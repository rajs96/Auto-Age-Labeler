# %%
import numpy as np
from keras.models import load_model
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
X_train = np.load('training_feature_arr_MLP.npy')
X_test = np.load('testing_feature_arr_MLP.npy')
y_train = np.load('training_labels_MLP.npy')
y_test = np.load('testing_labels_MLP.npy')
model_3 = load_model('MLP_Model3.h5')

# %%
# import pickle
import pickle
from sklearn.feature_selection import SelectFromModel
# select features based on Linear SVC feature selector

# load in feature selector
feature_selector = pickle.load( open( "MLP_Model3_featureSelector.pickle", "rb" ) )
# transform training data
X_train = feature_selector.transform(X_train)
# transform testing data
X_test = feature_selector.transform(X_test)

# load in standard scaler
scaler = pickle.load( open("MLP_Model3_standardScaler.pickle","rb" ) )
# transform training data
X_train = scaler.transform(X_train)
# transform testint data
X_test = scaler.transform(X_test)
# Out:
# /anaconda2/lib/python2.7/site-packages/sklearn/base.py:251: UserWarning: Trying to unpickle estimator LinearSVC from version 0.20.3 when using version 0.20.1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /anaconda2/lib/python2.7/site-packages/sklearn/base.py:251: UserWarning: Trying to unpickle estimator SelectFromModel from version 0.20.3 when using version 0.20.1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /anaconda2/lib/python2.7/site-packages/sklearn/base.py:251: UserWarning: Trying to unpickle estimator StandardScaler from version 0.20.3 when using version 0.20.1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
# load in model_results function
from multiclass_results_fn import print_model_results

# %%
class_names = ['teens','twenties','thirties','fourties','fifties',
              'sixties','seventies','eighties']
print_model_results(model_3,X_train,X_test,y_train,y_test,class_names)
# Out:
# 1542/1542 [==============================] - 0s 180us/step
# Results on primary testing set:
# Loss: 0.460984511637
# Accuracy: 0.881322957121
#               precision    recall  f1-score   support
#
#        teens       0.88      0.77      0.82       117
#     twenties       0.85      0.90      0.87       466
#     thirties       0.90      0.86      0.88       389
#     fourties       0.85      0.88      0.87       236
#      fifties       0.92      0.91      0.92       205
#      sixties       0.95      0.94      0.95        88
#    seventies       0.94      0.86      0.90        36
#     eighties       1.00      1.00      1.00         5
#
#    micro avg       0.88      0.88      0.88      1542
#    macro avg       0.91      0.89      0.90      1542
# weighted avg       0.88      0.88      0.88      1542
