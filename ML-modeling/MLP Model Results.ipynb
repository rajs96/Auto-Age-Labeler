# %% [markdown]
# # MLP Model Results

# %% [markdown]
# Here, we will output the results of two MLP models, using the multiclass results function we have defined within this directory.

# %%
import numpy as np
from keras.models import load_model
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
X_train = np.load('training_feature_arr_MLP_Model1.npy')
X_test_model2 = np.load('testing_feature_arr_MLP_Model1.npy')
y_train = np.load('training_labels_MLP.npy')
y_test = np.load('testing_labels_MLP.npy')
model_1 = load_model('MLP_Model1.h5') # it was renamed

# %%
# load in model_results function
from multiclass_results_fn import print_model_results

# %% [markdown]
# # MLP Model 1 Results

# %%
class_names = ['teens','twenties','thirties','fourties','fifties',
              'sixties','seventies','eighties']
print_model_results(model_1,X_train_model1,X_test_model2,y_train,y_test,class_names)
# Out:
# 1542/1542 [==============================] - 0s 158us/step
# Results on primary testing set:
# Loss: 0.516410969536
# Accuracy: 0.819714656213
#               precision    recall  f1-score   support
#
#        teens       0.82      0.73      0.77       117
#     twenties       0.80      0.84      0.82       466
#     thirties       0.81      0.79      0.80       389
#     fourties       0.79      0.78      0.79       236
#      fifties       0.87      0.87      0.87       205
#      sixties       0.92      0.91      0.91        88
#    seventies       0.86      0.86      0.86        36
#     eighties       0.75      0.60      0.67         5
#
#    micro avg       0.82      0.82      0.82      1542
#    macro avg       0.83      0.80      0.81      1542
# weighted avg       0.82      0.82      0.82      1542

# %% [markdown]
# # MLP Model 2 Results

# %%
X_train_model2 = np.load('training_feature_arr_MLP_Model2.npy')
X_test_model2 = np.load('testing_feature_arr_MLP_Model2.npy')
model_2 = load_model('MLP_Model2.h5')
print_model_results(model_2,X_train_model2,X_test_model2,y_train,y_test,class_names)
# Out:
# 1542/1542 [==============================] - 0s 156us/step
# Results on primary testing set:
# Loss: 0.486770614962
# Accuracy: 0.815823605784
#               precision    recall  f1-score   support
#
#        teens       0.83      0.71      0.76       117
#     twenties       0.79      0.84      0.82       466
#     thirties       0.77      0.81      0.79       389
#     fourties       0.82      0.79      0.80       236
#      fifties       0.91      0.84      0.88       205
#      sixties       0.87      0.84      0.86        88
#    seventies       0.89      0.86      0.87        36
#     eighties       0.80      0.80      0.80         5
#
#    micro avg       0.82      0.82      0.82      1542
#    macro avg       0.84      0.81      0.82      1542
# weighted avg       0.82      0.82      0.82      1542
