# %% [markdown]
# # Final Model Training

# %% [markdown]
# Here, we will train the final model and export it so it can be used in the web application.

# %% [markdown]
# Many of the same steps are taken in the other notebooks, so we will not focus too much on describing the steps that are being taken.

# %%
# so we have access to the Google Drive filesystem
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# necessary imports
import os
import pandas as pd
import numpy as np

# so we can access local modules within Colab
os.chdir('/content/drive/My Drive/auto-age-detector-model')

# feature selection defined functions
from feature_selection import tree_based_feature_selection

# model creation
from models import create_model

# for feature scaling
from sklearn.preprocessing import StandardScaler

# %%
df_train = pd.read_csv('data/audio_training_data_cleaned.csv').drop(columns=['Unnamed: 0','filename'])
# drop any null values we may have forgotten
df_train = df_train.dropna(how='any',axis=0)
X_train = df_train.drop(columns=['age'],axis=1)
y_train = df_train['age']

# %%
X_train,data_transformer = tree_based_feature_selection(X_train,y_train,
                                                        n_estimators=75)

# %%
replaced = {'teens':0,'twenties':1,'thirties':2,'fourties':3,'fifties':4,
            'sixties':5,'seventies':6,'eighties':7}

# https://stackoverflow.com/questions/29831489/convert-array-of-indices-to-1-hot-encoded-numpy-array

# need to put one hot encoded in keras model
y_train_ohe = y_train.replace(replaced)
y_train_ohe = np.eye(np.max(y_train_ohe)+1)[y_train_ohe]

# %%
# standard scaler
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)

# %%
# ensure reproducible results
from numpy.random import seed
seed(1)

# %%
X_train.shape
# Out:
# (73765, 85)

# %%
# get the model
model = create_model(dropout=0.1,learning_rate=1e-3)

model.fit(X_train,y_train_ohe,batch_size=32,validation_split=0.15,
          epochs=40)
# Out:
# Train on 62700 samples, validate on 11065 samples
# Epoch 1/40
# 62700/62700 [==============================] - 14s 229us/step - loss: 1.3537 - acc: 0.4816 - val_loss: 1.0789 - val_acc: 0.5980
# Epoch 2/40
# 62700/62700 [==============================] - 14s 221us/step - loss: 1.0448 - acc: 0.6130 - val_loss: 0.8984 - val_acc: 0.6831
# Epoch 3/40
# 62700/62700 [==============================] - 14s 222us/step - loss: 0.9137 - acc: 0.6647 - val_loss: 0.8034 - val_acc: 0.7155
# Epoch 4/40
# 62700/62700 [==============================] - 14s 222us/step - loss: 0.8219 - acc: 0.7019 - val_loss: 0.7315 - val_acc: 0.7376
# Epoch 5/40
# 62700/62700 [==============================] - 14s 228us/step - loss: 0.7577 - acc: 0.7256 - val_loss: 0.6801 - val_acc: 0.7587
# Epoch 6/40
# 62700/62700 [==============================] - 14s 221us/step - loss: 0.7128 - acc: 0.7434 - val_loss: 0.6470 - val_acc: 0.7713
# Epoch 7/40
# 62700/62700 [==============================] - 14s 216us/step - loss: 0.6787 - acc: 0.7544 - val_loss: 0.6208 - val_acc: 0.7818
# Epoch 8/40
# 62700/62700 [==============================] - 14s 219us/step - loss: 0.6442 - acc: 0.7677 - val_loss: 0.6023 - val_acc: 0.7883
# Epoch 9/40
# 62700/62700 [==============================] - 14s 215us/step - loss: 0.6166 - acc: 0.7775 - val_loss: 0.5864 - val_acc: 0.7932
# Epoch 10/40
# 62700/62700 [==============================] - 15s 233us/step - loss: 0.5962 - acc: 0.7858 - val_loss: 0.5726 - val_acc: 0.7961
# Epoch 11/40
# 62700/62700 [==============================] - 14s 216us/step - loss: 0.5775 - acc: 0.7923 - val_loss: 0.5609 - val_acc: 0.8043
# Epoch 12/40
# 62700/62700 [==============================] - 14s 221us/step - loss: 0.5551 - acc: 0.8008 - val_loss: 0.5537 - val_acc: 0.8070
# Epoch 13/40
# 62700/62700 [==============================] - 14s 226us/step - loss: 0.5427 - acc: 0.8059 - val_loss: 0.5378 - val_acc: 0.8149
# Epoch 14/40
# 62700/62700 [==============================] - 14s 219us/step - loss: 0.5276 - acc: 0.8096 - val_loss: 0.5369 - val_acc: 0.8161
# Epoch 15/40
# 62700/62700 [==============================] - 14s 221us/step - loss: 0.5173 - acc: 0.8161 - val_loss: 0.5268 - val_acc: 0.8192
# Epoch 16/40
# 62700/62700 [==============================] - 13s 215us/step - loss: 0.5079 - acc: 0.8165 - val_loss: 0.5233 - val_acc: 0.8215
# Epoch 17/40
# 62700/62700 [==============================] - 14s 221us/step - loss: 0.5002 - acc: 0.8215 - val_loss: 0.5115 - val_acc: 0.8228
# Epoch 18/40
# 62700/62700 [==============================] - 14s 221us/step - loss: 0.4859 - acc: 0.8251 - val_loss: 0.5139 - val_acc: 0.8270
# Epoch 19/40
# 62700/62700 [==============================] - 14s 218us/step - loss: 0.4754 - acc: 0.8295 - val_loss: 0.5009 - val_acc: 0.8269
# Epoch 20/40
# 62700/62700 [==============================] - 14s 218us/step - loss: 0.4699 - acc: 0.8324 - val_loss: 0.4850 - val_acc: 0.8337
# Epoch 21/40
# 62700/62700 [==============================] - 14s 220us/step - loss: 0.4604 - acc: 0.8372 - val_loss: 0.4903 - val_acc: 0.8315
# Epoch 22/40
# 62700/62700 [==============================] - 13s 214us/step - loss: 0.4527 - acc: 0.8387 - val_loss: 0.4803 - val_acc: 0.8356
# Epoch 23/40
# 62700/62700 [==============================] - 14s 220us/step - loss: 0.4502 - acc: 0.8407 - val_loss: 0.4844 - val_acc: 0.8327
# Epoch 24/40
# 62700/62700 [==============================] - 14s 223us/step - loss: 0.4389 - acc: 0.8444 - val_loss: 0.4829 - val_acc: 0.8360
# Epoch 25/40
# 62700/62700 [==============================] - 13s 214us/step - loss: 0.4368 - acc: 0.8444 - val_loss: 0.4837 - val_acc: 0.8349
# Epoch 26/40
# 62700/62700 [==============================] - 14s 221us/step - loss: 0.4332 - acc: 0.8449 - val_loss: 0.4758 - val_acc: 0.8375
# Epoch 27/40
# 62700/62700 [==============================] - 14s 220us/step - loss: 0.4238 - acc: 0.8508 - val_loss: 0.4817 - val_acc: 0.8371
# Epoch 28/40
# 62700/62700 [==============================] - 14s 219us/step - loss: 0.4184 - acc: 0.8511 - val_loss: 0.4736 - val_acc: 0.8410
# Epoch 29/40
# 62700/62700 [==============================] - 14s 215us/step - loss: 0.4129 - acc: 0.8526 - val_loss: 0.4757 - val_acc: 0.8398
# Epoch 30/40
# 62700/62700 [==============================] - 14s 217us/step - loss: 0.4152 - acc: 0.8527 - val_loss: 0.4650 - val_acc: 0.8418
# Epoch 31/40
# 62700/62700 [==============================] - 14s 218us/step - loss: 0.4105 - acc: 0.8532 - val_loss: 0.4683 - val_acc: 0.8401
# Epoch 32/40
# 62700/62700 [==============================] - 14s 221us/step - loss: 0.4014 - acc: 0.8576 - val_loss: 0.4633 - val_acc: 0.8433
# Epoch 33/40
# 62700/62700 [==============================] - 14s 222us/step - loss: 0.3990 - acc: 0.8571 - val_loss: 0.4626 - val_acc: 0.8453
# Epoch 34/40
# 62700/62700 [==============================] - 14s 220us/step - loss: 0.3982 - acc: 0.8583 - val_loss: 0.4658 - val_acc: 0.8439
# Epoch 35/40
# 62700/62700 [==============================] - 14s 219us/step - loss: 0.3973 - acc: 0.8580 - val_loss: 0.4636 - val_acc: 0.8437
# Epoch 36/40
# 62700/62700 [==============================] - 14s 222us/step - loss: 0.3898 - acc: 0.8611 - val_loss: 0.4681 - val_acc: 0.8450
# Epoch 37/40
# 62700/62700 [==============================] - 14s 219us/step - loss: 0.3858 - acc: 0.8642 - val_loss: 0.4595 - val_acc: 0.8472
# Epoch 38/40
# 62700/62700 [==============================] - 14s 216us/step - loss: 0.3778 - acc: 0.8667 - val_loss: 0.4514 - val_acc: 0.8503
# Epoch 39/40
# 62700/62700 [==============================] - 14s 216us/step - loss: 0.3750 - acc: 0.8673 - val_loss: 0.4528 - val_acc: 0.8514
# Epoch 40/40
# 62700/62700 [==============================] - 13s 213us/step - loss: 0.3793 - acc: 0.8664 - val_loss: 0.4505 - val_acc: 0.8502

# %% [markdown]
# We save the model.

# %%
model.save('model1.h5')
from google.colab import files
files.download(os.path.join(os.getcwd(),'model1.h5'))

# %% [markdown]
# We also save the feature selector and scaler for consistency.

# %%
import pickle
with open('feature_selector.pkl','wb') as feat_sel:
  pickle.dump(data_transformer,feat_sel)

# %%
with open('standard_scaler.pkl','wb') as standard_scaler:
  pickle.dump(scaler,standard_scaler)

# %%
test = np.array([1,3,4,3])
isinstance(test,np.ndarray)
# Out:
# True
